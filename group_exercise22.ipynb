# %% [markdown]
# ### 1. Use Splinter and/or Beautiful Soup to scrape https://www.dndbeyond.com/classes, and pull out all class names. Store these in a dataframe.

# %%
from bs4 import BeautifulSoup as bs
import requests

#need to look at terms and conditions to know if you can scrape the website
#most websites have a file called robots.txt that you can look at to see
#if scraping is allowed. ex: google.com/robots.txt
url = 'https://en.wikipedia.org/wiki/Main_Page'

# %%
#get page with requests
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = bs(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
print(soup.title)
# Out:
# <title>Wikipedia, the free encyclopedia</title>

# %%
all_divs = soup.find_all('div',class_='mp-bordered')
all_divs
# Out:
# [<div class="mp-bordered" id="mp-topbanner">
#  <div id="mp-welcomecount">
#  <div id="mp-welcome">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a>,</div>
#  <div id="mp-free">the <a href="/wiki/Free_content" title="Free content">free</a> <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> that <a href="/wiki/Help:Introduction_to_Wikipedia" title="Help:Introduction to Wikipedia">anyone can edit</a>.</div>
#  <div id="articlecount"><a href="/wiki/Special:Statistics" title="Special:Statistics">6,347,359</a> articles in <a href="/wiki/English_language" title="English language">English</a></div>
#  </div>
#  <ul id="mp-portals">
#  <li><a href="/wiki/Portal:The_arts" title="Portal:The arts">The arts</a></li>
#  <li class="portal-vmid"><a href="/wiki/Portal:Biography" title="Portal:Biography">Biography</a></li>
#  <li class="portal-vbot"><a href="/wiki/Portal:Geography" title="Portal:Geography">Geography</a></li>
# ...

# %%
import pandas as pd
page_one_results = []
for div in all_divs:
    try:
        headline_text = div.find('span', class_="mw-headline").text
        area = div.find('h2', class_='mp-h2').text
        quote_dict = {'headline':headline_text,
                     'area':area}
        page_one_results.append(quote_dict)
    except AttributeError as e:
        print(e)
page_one_df = pd.DataFrame(page_one_results)
page_one_df
# Out:
# 'NoneType' object has no attribute 'text'
#                      headline                        area
# 0  From today's featured list  From today's featured list
# 1    Today's featured picture    Today's featured picture
# 2    Other areas of Wikipedia    Other areas of Wikipedia

# %%
# !pip install splinter
# Out:
# ...
#   Using cached splinter-0.15.0-py3-none-any.whl (37 kB)
# ...

# %%
# !pip install selenium

# %%
# !pip install webdriver-manager

# %%
# !pip install webdriver_manager

# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
executable_path = {'executable_path':ChromeDriverManager().install()}
browser = Browser('chrome',**executable_path, headless=False)
url="https://www.dndbeyond.com/classes"
browser.visit(url)
soup = bs(browser.html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2da7d14defa9> in <module>
#       1 from bs4 import BeautifulSoup as bs
# ----> 2 from splinter import Browser
#       3 from webdriver_manager.chrome import ChromeDriverManager
#       4 executable_path = {'executable_path':ChromeDriverManager().install()}
#       5 browser = Browser('chrome',**executable_path, headless=False)
#
# ~\anaconda3\lib\site-packages\splinter\__init__.py in <module>
#       3 # license that can be found in the LICENSE file.
#       4
# ----> 5 from splinter.browser import Browser  # NOQA
#       6
#       7
#
# ~\anaconda3\lib\site-packages\splinter\browser.py in <module>
#      14 from selenium.common.exceptions import WebDriverException
#      15
# ---> 16 from splinter.driver.webdriver.firefox import WebDriver as FirefoxWebDriver
# ...

# %%
from selenium import webdriver
from Library import ConfigReader
browser = Browser("chrome", **executable_path, headless=False)
# get page for a given match
match_url = 'https://www.dndbeyond.com/classes'
browser.visit(match_url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-ed642e2c7139> in <module>
# ----> 1 from selenium import webdriver
#       2 from Library import ConfigReader
#       3 browser = Browser("chrome", **executable_path, headless=False)
#       4 # get page for a given match
#       5 match_url = 'https://www.dndbeyond.com/classes'
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\__init__.py in <module>
#      16 # under the License.
#      17
# ---> 18 from .firefox.webdriver import WebDriver as Firefox  # noqa
#      19 from .firefox.firefox_profile import FirefoxProfile  # noqa
#      20 from .firefox.options import Options as FirefoxOptions  # noqa
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in <module>
#      27
#      28 from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = 'http://dndbeyond.com/classes'
browser.visit(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-fe8e041c5d6e> in <module>
# ----> 1 from selenium import webdriver
#       2 from webdriver_manager.chrome import ChromeDriverManager
#       3 executable_path = {'executable_path': ChromeDriverManager().install()}
#       4 browser = Browser('chrome', **executable_path, headless=False)
#       5 url = 'http://dndbeyond.com/classes'
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\__init__.py in <module>
#      16 # under the License.
#      17
# ---> 18 from .firefox.webdriver import WebDriver as Firefox  # noqa
#      19 from .firefox.firefox_profile import FirefoxProfile  # noqa
#      20 from .firefox.options import Options as FirefoxOptions  # noqa
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in <module>
#      27
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
browser = webdriver.Chrome(ChromeDriverManager().install())
url = 'http://dndbeyond.com/classes'
browser.get(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-c7a3f569b312> in <module>
# ----> 1 from selenium import webdriver
#       2 from webdriver_manager.chrome import ChromeDriverManager
#       3 browser = webdriver.Chrome(ChromeDriverManager().install())
#       4 url = 'http://dndbeyond.com/classes'
#       5 browser.get(url)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\__init__.py in <module>
#      16 # under the License.
#      17
# ---> 18 from .firefox.webdriver import WebDriver as Firefox  # noqa
#      19 from .firefox.firefox_profile import FirefoxProfile  # noqa
#      20 from .firefox.options import Options as FirefoxOptions  # noqa
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in <module>
#      27
#      28 from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
# ...

# %%
from selenium import webdrive
driver = webdriver.chrome()
driver.get('http://dndbeyond.com/classes')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-29b4f73a9864> in <module>
# ----> 1 from selenium import webdrive
#       2 driver = webdriver.chrome()
#       3 driver.get('http://dndbeyond.com/classes')
#
# ImportError: cannot import name 'webdrive' from 'selenium' (unknown location)

# %%
# import required modules
from bs4 import BeautifulSoup
import requests
  
# get URL
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
  
# scrape webpage
soup = BeautifulSoup(page.content, 'html.parser')
  
# create object
object = soup.find(id="mp-left")
  
# find tags
items = object.find_all(class_="mp-h2")
result = items[0]
  
# display tags
print(result.prettify())
# Out:
# <h2 class="mp-h2" id="mp-tfa-h2">
#  <span id="From_today.27s_featured_article">
#  </span>
#  <span class="mw-headline" id="From_today's_featured_article">
#   From today's featured article
#  </span>
# </h2>

# %% [markdown]
# ### 2. Now, alter 1 to click on each class name to go to the more detailed page, and pull out the first paragraph about each class. Store these in a dataframe. Your dataframe should have two columns
